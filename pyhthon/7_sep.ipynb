# %%
lst =['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle','Amazon']
n = len(lst)
middle =[]
if n %2==0:
    middle.append(lst[n//2-1])
    middle.append(lst[n//2])
    print(*middle)
else:
    middle.append(lst[n//2])
    print(*middle)
# Out:
# Apple
