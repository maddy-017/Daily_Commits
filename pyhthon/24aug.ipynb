# %%
# The range() function generates a sequence of integers starting at 0 and stopping right before the given number.
# It produces the sequence: 0, 1, 2, 3, 4, 5. These numbers match the index positions of the letters in 'Python'
language = 'Python'

for i in range(len(language)):
    print(language[i])
# Out:
# P
# y
# t
# h
# o
# n
