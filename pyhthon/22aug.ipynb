# %%
list = [1,2,3]
print(len(list))
print(list[0],list[-1],list[1])
# Out:
# 3
# 1 3 2

# %%
lst= ["bangi", 18, 5.6,' akhand single', 'siid']
print(lst)
# Out:
# ['bangi', 18, 5.6, ' akhand single', 'siid']

# %%
it_companies = [
    'Facebook',
    'Google',
    'Microsoft',
    'Apple',
    'IBM',
    'Oracle',
    'Amazon'
]
it_companies[3] = 'nvidia'
print(it_companies)
print(it_companies.append('anthropic'))
print(it_companies)
print(it_companies.insert(4,'bayn'))
it_companies[1] = it_companies[1].upper()

print(it_companies)
print('#;  '.join(it_companies))
print('IBM' in it_companies)
it_companies.sort()
print(it_companies)
it_companies.reverse()
print(it_companies[0:3])
it_companies.pop(0)
print(it_companies[-3:0])
print(it_companies)
print(it_companies)
print(it_companies)
# Out:
# ['Facebook', 'Google', 'Microsoft', 'nvidia', 'IBM', 'Oracle', 'Amazon']
# None
# ['Facebook', 'Google', 'Microsoft', 'nvidia', 'IBM', 'Oracle', 'Amazon', 'anthropic']
# None
# ['Facebook', 'GOOGLE', 'Microsoft', 'nvidia', 'bayn', 'IBM', 'Oracle', 'Amazon', 'anthropic']
# Facebook#;  GOOGLE#;  Microsoft#;  nvidia#;  bayn#;  IBM#;  Oracle#;  Amazon#;  anthropic
# True
# ['Amazon', 'Facebook', 'GOOGLE', 'IBM', 'Microsoft', 'Oracle', 'anthropic', 'bayn', 'nvidia']
# ['nvidia', 'bayn', 'anthropic']
# []
# ['bayn', 'anthropic', 'Oracle', 'Microsoft', 'IBM', 'GOOGLE', 'Facebook', 'Amazon']
# []
# []

# %%
front_end = ['HTML', 'CSS', 'JS', 'React', 'Redux']
back_end = ['Node', 'Express', 'MongoDB']

full_stack = front_end + back_end
full_stack = full_stack.copy()

full_stack.insert(5, 'Python')
full_stack.insert(6, 'SQL')

print(full_stack)
# Out:
# ['HTML', 'CSS', 'JS', 'React', 'Redux', 'Python', 'SQL', 'Node', 'Express', 'MongoDB']

# %%
ages = [19, 22, 19, 24, 20, 25, 26, 24, 25, 24]
ages.sort()
print(ages)
min = ages[0]
max = ages[-1]
print(min,max)
ages.append(min)
ages.append(max)
print(ages)
# Out:
# [19, 19, 20, 22, 24, 24, 24, 25, 25, 26]
# 19 26
# [19, 19, 20, 22, 24, 24, 24, 25, 25, 26, 19, 26]

# %%
# syntax
dct = {'key1':'value1', 'key2':'value2', 'key3':'value3', 'key4':'value4'}
dct['key1'] = 'value-one'
print(dct)
# Out:
# {'key1': 'value-one', 'key2': 'value2', 'key3': 'value3', 'key4': 'value4'}

# %%
p
