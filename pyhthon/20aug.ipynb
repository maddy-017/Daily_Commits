# %%
company = 'Codingforall'
tenth = company[10]
print(tenth)
# Out:
# l

# %%
challenge = 'thirty days of python'
print(challenge.split()) # ['thirty', 'days', 'of', 'python']
challenge = 'thirty, days, of, python'
print(challenge.split(', '))
# Out:
# ['thirty', 'days', 'of', 'python']
# ['thirty', 'days', 'of', 'python']

# %%
sent = ' Coding for all '
# words = sent.split()
# abbre = words[0][0] + words[1][0]+ words [2][0]
# print(abbre)
# print(sent.endswith('Coding'))text = "   Coding For All      "

print(sent.strip())
# Out:
# Coding for all

# %%
sent ='You cannot end a sentence with because because because is a conjunction'
# print(sent.find('because'))
start = sent.find("because")

end = sent.find("is")

print(sent[start:end].strip())
# Out:
# because because because

# %%
libs = ['Django', 'Flask', 'Bottle', 'Pyramid', 'Falcon']
libs1 = ' #'.join(libs)
print(libs1)
# Out:
# Django #Flask #Bottle #Pyramid #Falcon

# %%
sent = "I am enjoying this challenge.\nI just wonder what is next."
print(sent)
# Out:
# I am enjoying this challenge.
# I just wonder what is next.

# %%
sent = "Name\tAge\tCountry\tCity\nAsabeneh\t250\tFinland\tHelsinki"

print(sent)
# Out:
# Name	Age	Country	City
# Asabeneh	250	Finland	Helsinki

# %%
radius = 10
area = 3.14 * radius ** 2
print("The area of a circle with radius %d is %d meters square."%(radius,area))
# Out:
# The area of a circle with radius 10 is 314 meters square.

# %%
abd = [1,1,1]
print(len(abd))
# Out:
# 3

# %%
empty_list = [,c,c] # this is an empty list, no item in the list
print(len(empty_list)) # 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 empty_list = [c,c,c] # this is an empty list, no item in the list
#       2 print(len(empty_list)) # 0
#
# NameError: name 'c' is not defined
