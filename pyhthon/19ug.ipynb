# %%
name_init = 10 
print("name_init",name_init)
# Out:
# name_init 10

# %%
print('Floating Point Number, PI', 3.14)
# Out:
# Floating Point Number, PI 3.14

# %%
radius=int(input(" radius of the circle is : "))
area = 3.14 * radius **2
print(area)
# Out:
#  radius of the circle is :  9
# 254.34

# %%
print('4 is 2 ** 2:', 4 is 2 ** 2)   # True
# Out:
# 4 is 2 ** 2: True
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# /var/folders/db/xnjxxmld6v54jx9q_fth3s4r0000gn/T/ipykernel_42380/3603715355.py:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print('4 is 2 ** 2:', 4 is 2 ** 2)   # True

# %%
slope = 2
# y intercep
x =0

y_intercept= 2 *x-2
y = 0 
x_intercept = (2+ y)/2 
print(y_intercept)
print(x_intercept)
# Out:
# -2
# 1.0

# %%
slope1 = 2
# y intercep
x =0

y_intercept= 2 *x-2
y = 0 
x_intercept = (2+ y)/2 
print(y_intercept)
print(x_intercept)
x1 = 2
x2= 2
y1 = 6 
y2 = 10 
slope =x2 - x1 /y2 - y1
print ( "Slope : ",slope )
print(((x2 - x1)**2 +(y2 - y1)**2)**0.5)
print(slope ==slope1)
# Out:
# -2
# 1.0
# Slope :  -4.2
# 4.0
# False

# %%
print(len('python')<len('dragon'))
# Out:
# False

# %%
hours = float(input(" Enter the hours "))
rate = float(input(" Enter the rate per hour"))
earning = hours * rate
earning =int(earning)
print("you weekly Earning is ", earning)
# Out:
#  Enter the hours  4
#  Enter the rate per hour 45
# you weekly Earning is  180

# %%
years = int(input("Enter the no. of years you have lived : "))
print("You have lived" ,years * 365 * 24 * 60 * 60 , "seconds" )
# Out:
# Enter the no. of years you have lived :  18
# You have lived 567648000 seconds

# %%
print('''1 1 1 1 1
2 1 2 4 8
3 1 3 9 27
4 1 4 16 64
5 1 5 25 125''')
# Out:
# 1 1 1 1 1
# 2 1 2 4 8
# 3 1 3 9 27
# 4 1 4 16 64
# 5 1 5 25 125

# %%
language = 'Python'
first_letter = language[0]
print(first_letter) # P
second_letter = language[1]
print(second_letter) # y
last_index = len(language) - 1
last_letter = language[last_index]
print(last_letter) # n
# Out:
# P
# y
# n

# %%
language = 'Python'
first_letter = language[0]
print(first_letter) # P
second_letter = language[1]
print(second_letter) # y
last_index = len(language) - 1
last_letter = language[last_index]
print(last_letter) # n
# Out:
# P
# y
# n

# %%
company = "coding For All"
# print(len(company))
# print(company.upper())
# print(company.capitalize())
# print(company.title())
# print(company.swapcase())
# print (company[0:6])
# index = 'coding'
# print(company.index(index))
# print(company.replace('coding' , 'python'))
# print(company.replace('coding' , 'python'))
# print(company.split())
# ca = 'i'
tenth_character = company[10]
print(tenth_character)

# %%
FAANG ="Facebook, Google, Microsoft, Apple, IBM, Oracle, Amazon"
print(FAANG.split(','))
# Out:
# ['Facebook', ' Google', ' Microsoft', ' Apple', ' IBM', ' Oracle', ' Amazon']

# %%
sent = 'You cannot end a sentence with because because because is a conjunction'
# print(sent.index('cannot'))
print(sent[0])
# Out:
# 4
