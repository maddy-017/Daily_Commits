# %%
lst =['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle','Amazon','nvidia']
n = len(lst)
middle =[]
if n %2==0:
    middle.append(lst[n//2-1])
    middle.append(lst[n//2])
    print(*middle)
else:
    middle.append(lst[n//2])
    print(*middle)
# Out:
# ['Apple', 'IBM']

# %%
lst =['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle','Amazon','nvidia']
print(lst)
# Out:
# ['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon', 'nvidia']

# %%
print('#'.join(lst))
'Google' in lst
lst.sort()
lst.reverse()
print(lst[0:3])
print(lst[-3:])
middle_three = len(lst)
# Out:
# nvidia#OpenAI#Microsoft#IBM#Google#Facebook#Apple#Amazon
# ['nvidia', 'OpenAI', 'Microsoft']
# ['Facebook', 'Apple', 'Amazon']
# [[4, 3, 5]]
