# %%
(base) amueedbangi@Abduls-MacBook-Air ~ % ps aux | grep fswatch | grep -v grep
amueedbangi      69984   0.0  0.0 442503104   5936   ??  S     4:47PM   0:00.01 /opt/homebrew/bin/fswatch -o .
(base) amueedbangi@Abduls-MacBook-Air ~ % echo "test" > /Users/amueedbangi/COLLAGE/testfile.txt
sleep 3
cd /Users/amueedbangi/COLLAGE
git log -1
commit 59c191dd60bc1e03f7b3a90d6451bb4f3f9a2c19 (HEAD -> main)
Author: maddy-017 <bangiabdulmoid@gmail.com>
Date:   Wed Sep 9 16:48:46 2026 +0530

    Auto-commit: 2026-09-09 16:48:46
(base) amueedbangi@Abduls-MacBook-Air COLLAGE %
